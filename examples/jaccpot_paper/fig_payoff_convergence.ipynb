# %% [markdown]
# # fig_payoff_convergence
#
# Gradient-based recovery of a parametric potential from synthetic kinematics.
#
# Loads from `../../results/payoff/recovery.json` (produced by the corresponding script in `bench/`, not recomputed here). Never call jaccpot/jax in this notebook -- if the data doesn't exist yet, go run the bench script first.

# %%
import json
import pathlib

import matplotlib.pyplot as plt

DATA_PATH = pathlib.Path('../../results/payoff/recovery.json')
with open(DATA_PATH) as f:
    data = json.load(f)
data

# %%
# TODO: plot from `data` above, then save into the paper repo's
# figures/ directory, e.g.:
# fig, ax = plt.subplots(figsize=(4.5, 3.4))
# ...
# fig.savefig('/path/to/jaccpot-paper-i/figures/payoff_convergence.pdf', bbox_inches='tight')
