# %% [markdown]
# # fig_comm_overhead
#
# Communication vs. compute fraction vs. #GPUs (pivot long-format stage data here).
#
# Loads from `../../results/multigpu/comm_overhead.json` (produced by the corresponding script in `bench/`, not recomputed here). Never call jaccpot/jax in this notebook -- if the data doesn't exist yet, go run the bench script first.

# %%
import json
import pathlib

import matplotlib.pyplot as plt

DATA_PATH = pathlib.Path('../../results/multigpu/comm_overhead.json')
with open(DATA_PATH) as f:
    data = json.load(f)
data

# %%
# TODO: plot from `data` above, then save into the paper repo's
# figures/ directory, e.g.:
# fig, ax = plt.subplots(figsize=(4.5, 3.4))
# ...
# fig.savefig('/path/to/jaccpot-paper-i/figures/comm_overhead.pdf', bbox_inches='tight')
